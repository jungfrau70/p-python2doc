# %%
import datetime
from chart import *

# %%
# 날짜
today = datetime.date.today()

y = today.year
m = today.month
d = today.day
w = today.weekday()

# report version
month = '6월'
v = '1'
region = 'KR'

# %% [markdown]
# ## 보고서 표지 (커버 쉬트)

# %%
document.add_heading(f'[2022.06] {region} Cloud Infra 운영', level=0)
document.add_heading(f'{y}.{m}.{d}', level=1)
document.add_heading(f'클라우드운영센터', level=1)

# %% [markdown]
# ## 요약

# %%
# Data Loading
base_path = r"./data/요약_202206_서비스관리_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   년도           56 non-null     object
#  1   월            56 non-null     object
#  2   리전           56 non-null     object
#  3   AZ           56 non-null     object
#  4   테넌트          56 non-null     object
#  5   진행상태         56 non-null     object
#  6   성패           33 non-null     object
#  7   Description  56 non-null     object
#  8   주간           56 non-null     object
#  9   월간           27 non-null     object
# dtypes: object(10)
# memory usage: 4.5+ KB

# %%
df.describe()
# Out:
#          년도   월  리전   AZ  테넌트 진행상태  성패  \
# count    56  56  56   56   56   56  33
# unique    1   6   8    2    4    2   1
# top     22년  6월  KR  1센터  PRD   완료  성공
# freq     56  32  12   50   36   33  33
#
#                                               Description  주간  월간
# count                                                  56  56  27
# unique                                                 49   1   1
# top     클라우드 플랫폼(opentsack) 보안 설정 현황 확인 요청\n중국 GCS시스템에...   O   O
# freq                                                    2  56  27

# %%
# Pivoting
pivot = getPivotTable(df)

# %%
pivot
# Out:
#    리전  합계    비중
# 0  CN   2  40.0
# 1  KR   1  20.0
# 2  NA   1  20.0
# 3  SG   1  20.0

# %%
document.add_paragraph('서비스 관리', style='Intense Quote')
data = getdata()
chart = getTable(data)
document.add_picture(f'./charts/sm_{y}_{m}_{d}_{v}.png')

# %% [markdown]
# ## 1.1 모니터링(인시던트핸들링)

# %%
import datetime
from chart import *

# Data Loading
base_path = r"./data/1_1_202206_모니터링_인시던트핸들링_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   월                     233 non-null    object
#  1   리전                    233 non-null    object
#  2   AZ                    233 non-null    float64
#  3   테넌트                   233 non-null    object
#  4   진행상태                  233 non-null    object
#  5   장애전파시간                233 non-null    object
#  6   날짜                    236 non-null    object
#  7   KST                   233 non-null    object
#  8   상황근무자                 233 non-null    object
#  9   엔지니어_L1               129 non-null    object
#  10  엔지니어_L2               74 non-null     object
#  11  발생인지시간                233 non-null    object
#  12  장애전파시간.1              233 non-null    object
#  13  장애 전파 소요 시간           233 non-null    object
#  14  공유 방법
# (How to share)  233 non-null    object
#  15  해결 일시(Resolved Time)  161 non-null    object
#  16  장애 내용                 233 non-null    object
#  17  장애대응조치내용              233 non-null    object
#  18  JIRA_Ticket_No        38 non-null     object
#  19  해결여부                  111 non-null    object
#  20  3선컨택여부                75 non-null     object
#  21  기타                    13 non-null     object
# dtypes: float64(1), object(21)
# memory usage: 41.7+ KB

# %%
df.describe()
# Out:
#                AZ
# count  233.000000
# mean     1.283262
# std      0.451552
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot, total = getPivotTable(df)
pivot
# Out:
#    리전  진행상태
# 0  CN    12
# 1  EU    26
# 2  IN     1
# 3  KR    61
# 4  NA    27
# 5  RU     3
# 6  SG     1
#    리전  합계    비중
# 0  KR  61  47.0
# 1  NA  27  21.0
# 2  EU  26  20.0
# 3  CN  12   9.0
# 4  RU   3   2.0
# 5  IN   1   1.0
# 6  SG   1   1.0

# %% [markdown]
# ### 비중 :: Piot Table

# %%
source = pivot
chart = getPieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{region}_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{region}_{y}_{m}_{d}_1.png')

# %%
document.add_picture(f'./charts/mon_{region}_{y}_{m}_{d}_1.png')

# %%
document.save('word.docx')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.2 이슈 관리

# %%
# Data Loading
base_path = r"./data/1_2_202206_이슈관리_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#         년도    월  리전   AZ  테넌트 진행상태    성패                                 상태  \
# 0   2022.0   1월  SG  1.0  STG   완료    성공  sg-stg-com-d-0103-10.sg.hcloud.io
# 1   2022.0   1월  SG  1.0  PRD   완료    성공   SG-LB02 interface error count 증가
# 2   2022.0   1월  SG  1.0  PRD   완료    성공                       SG BM Zabbix
# 3   2022.0   1월  RU  1.0  PRD   완료    성공                      러시아 글로벌 회선 작업
# 4   2022.0   1월  RU  1.0  PRD   완료    성공                    RU IPMI 스크립트 오류
# ..     ...  ...  ..  ...  ...  ...   ...                                ...
# 93  2022.0   6월  EU  1.0  PRD  진행중  None               EU-FW IPSECVPN 구성 요청
# 94  2022.0   6월  CN  1.0  PRD  진행중  None                운영계 VM 라이브마이그레이션 불가
# 95  2022.0   6월  EU  1.0  PRD  진행중  None  유럽 CCS 운영계 SAS(FAS8200) 사용률 92%초과
# 96  2022.0  6월   CN  1.0  STG  진행중  None             중국 검증계 UCS 유지보수 계약 대기중
# 97  2022.0  6월   KR  1.0  STG  진행중  None         내수 신검증계 Netapp 스토리지 사용량 증가
#
#                                            작업 / Title             시작일/Date  \
# 0   sg-stg-com-d-0103-10.sg.hcloud.io Memory Error...  2022-01-11T00:00:00
# 1                          SG-LB02 interface error 개선  2022-01-18T00:00:00
# 2                               SG BM Zabbix 대상 서버 추가          2022-01-18~
# 3                               한국 ↔ 러시아 글로벌 회선 장애 발생           2022.01.05
# 4                                     RU IPMI 스크립트 오류  2022-01-01T00:00:00
# ..                                                ...                  ...
# 93                               EU-FW IPSECVPN 구성 요청  2022-02-25T00:00:00
# 94                                       VM 마이그레이션 실패  2021-08-01T00:00:00
# 95                     ccseuvcrmp01,02_data_backup 회수  2022-04-28T00:00:00
# 96                                               None  2021-06-11T00:00:00
# 97  NVME Free Size on aggr_node01_NVMe_data less t...  2022-06-15T00:00:00
#
#                     완료일                                          배경 및 작업내용  \
# 0   2022-01-19T00:00:00  Uncorrectable multi-bit error.\nRMA\n→ VM 마이그레...
# 1   2022-01-19T00:00:00  SG-LB02 interface 2.2 error count 지속적으로 증가\n=>...
# 2   2022-01-24T00:00:00  싱가폴 BM zabbix HW장비 모니터링 대상 추가\n=> BL, SP, SL, ...
# 3            2022.01.05  01/15 저녁 7시경 러시아 클라우드 HW장비 Down 알람 발생\n=> 확인결과...
# 4            2022.01.24  RU PRD deploy 서버(10.107.17.24)에 대해 RU IPMI Swi...
# ..                  ...                                                ...
# 93                 None  EU CLOUD내 SBS와 AWS통신 필요\n=> IPSECVPN 터널링 구성 요청...
# 94                 None  중국 운영계 compute 서버 중 bios 2.8.2 버전의 VM에서 2.2.11...
# 95                 None  vcrm 데이터 복구 지원 -> backup 볼륨 총 2TB증설\n유럽 CCS 운영...
# 96                 None  중국 검증계 UCS 유지보수 계약 만료 (2021.4.30까지)\n\n중국 법인에서...
# 97                 None                               스냅샷 및 미사용 \n볼륨 삭제 진행
#
#                                                    비고
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 93                                                우전성
# 94  =HYPERLINK("https://cody-ims.autoever.com/brow...
# 95  =HYPERLINK("https://cody-ims.autoever.com/brow...
# 96  =HYPERLINK("https://cody-ims.autoever.com/brow...
# 97                                               None
#
# [98 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년도          98 non-null     float64
#  1   월           98 non-null     object
#  2   리전          98 non-null     object
#  3   AZ          98 non-null     float64
#  4   테넌트         98 non-null     object
#  5   진행상태        98 non-null     object
#  6   성패          82 non-null     object
#  7   상태          98 non-null     object
#  8   작업 / Title  97 non-null     object
#  9   시작일/Date    98 non-null     object
#  10  완료일         78 non-null     object
#  11  배경 및 작업내용   98 non-null     object
#  12  비고          73 non-null     object
# dtypes: float64(2), object(11)
# memory usage: 10.1+ KB

# %%
df.describe()
# Out:
#            년도         AZ
# count    98.0  98.000000
# mean   2022.0   1.040816
# std       0.0   0.198882
# min    2022.0   1.000000
# 25%    2022.0   1.000000
# 50%    2022.0   1.000000
# 75%    2022.0   1.000000
# max    2022.0   2.000000

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)

# %%
pivot
# Out:
#    리전  합계    비중
# 0  EU   6  46.0
# 1  CN   2  15.0
# 2  KR   2  15.0
# 3  NA   2  15.0
# 4  SG   1   8.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.3 장애 관리

# %%
# Data Loading
base_path = r"./data/1_3_202206_장애관리_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#        년도   월  리전   AZ  테넌트 진행상태     성패  \
# 0   2022년  1월  KR  1센터  PRD   완료     성공
# 1   2022년  1월  KR  1센터  STG   완료     성공
# 2   2022년  2월  KR  1센터  PRD   완료     성공
# 3   2022년  2월  KR  1센터  PRD   완료     성공
# 4   2022년  3월  KR  1센터  PRD   완료     성공
# 5   2022년  3월  KR  1센터  PRD   완료     성공
# 6   2022년  3월  NA  1센터  PRD   완료     성공
# 7   2022년  3월  NA  1센터  STG   완료     성공
# 8   2022년  4월  CN  1센터  PRD   완료     성공
# 9   2022년  4월  NA  1센터  PRD   완료     성공
# 10  2022년  5월  KR  2센터  PRD   완료     성공
# 11  2022년  5월  KR  2센터  PRD   완료     성공
# 12  2022년  5월  KR  1센터  PRD   완료     성공
# 13  2022년  5월  EU  1센터  PRD   완료     성공
# 14  2022년  6월  KR  1센터  PRD   완료     성공
# 15  2022년  6월  KR  1센터  PRD   완료     성공
# 16  2022년  6월  KR  2센터  STG   완료     성공
# 17  2022년  6월  KR  2센터  PRD   완료     성공
# 18  2022년  6월  NA  1센터  PRD  진행중  원인분석중
#
#                                            Task / Job  \
# 0                        해당 호스트 VM LB 인입 차단 후 호스트 리부팅
# 1                                                None
# 2   KRCloud-PRD-IPMI-R14 Ethernet15 구간 확인 요청\nkrcl...
# 3                          Netapp 볼륨 점검 및 벤더 케이스분석 의뢰
# 4   ccskrbigps03dnp02 리부팅 관련\nBAREMETAL krcloudprd...
# 5                통합계정 VM(account, profile) 장애관련 긴급 지원
# 6                                  북미 데이터 센터 쿨러 이상 발생
# 7                                  북미 데이터 센터 쿨러 이상 발생
# 8       NBU장비 출구 라우팅을 변경.\n접속 않되는거에 대하여 수동으로 라우팅을 추가.
# 9                                         DB Recovery
# 10                                        Host reboot
# 11                                   Rancher 서비스 down
# 12              내수 CCS 주간 5분 간격 배치잡 실패, push 알람 수신 실패
# 13                                       EDB Failover
# 14                                       RMA / 디스크 교체
# 15                                         네트워크 장비 점검
# 16  2센터 검증계 호스트 리부팅 반복\nkr-az2-com05-02r08.kr.hclo...
# 17                         2센터 Spine02 Interface Down
# 18                                        tibero down
#
#                                      System / Service                   Date  \
# 0                                 krcloudprdcomdr1510    2022-01-19T00:00:00
# 1          krcloudstgcomdr907.krcloud (10.10.175.171)    2022-01-17T00:00:00
# 2                                 krcloudprdcomdR1413    2022-02-04T00:00:00
# 3                                netapp(10.11.41.230)    2022-01-12T00:00:00
# 4   ccskrbigps03dnp02 (10.11.63.239)\nkrcloudprdco...    2022-02-13T00:00:00
# 5                                         UW-KRMTS-L7    2022-02-25T00:00:00
# 6                                       NA Datacenter    2022-03-11T00:00:00
# 7                                       NA Datacenter    2022-03-11T00:00:00
# 8                      ccscntmsdbp01 (10.124.253.152)    2022-04-05T00:00:00
# 9                  ccsnakmatmsdbp01\nccsnakmatmsdbp02   2022.04.18 07:44 KST
# 10                   kr-az2-com06-01r08.kr.hcloud.h53    2022-05-12T00:00:00
# 11                                 paas-prd-rancher02    2022-05-12T00:00:00
# 12         mysql/f3df43e3-c88f-425b-9560-d97ea7895d8d    2022-05-17T00:00:00
# 13                             ccseudbp01\nccseudbp02    2022-05-25T00:00:00
# 14                 krcloudprdcomdr1514\nccskrkafkap03    2022-06-09T00:00:00
# 15               KRCloud-PRD-BL-01\nKRCloud-PRD-L7-01    2022-05-24T00:00:00
# 16                   kr-az2-com05-02r08.kr.hcloud.h53  22/05/29\n~\n22/06/06
# 17                              Spine02\nCL03-D-01R08    2022-06-14T00:00:00
# 18  ccsnakcitmsdbp01 (10.112.203.219)\nccsnakcitms...    2022-05-01T00:00:00
#
#                                              Engineer  \
# 0                                   Subramanya Ambale
# 1                                        우리 올제 김성균 대리
# 2                                   심명보\n우리 올제 김성균 대리
# 3                                  정종인\n이테크시스템 허정수 과장
# 4                                    심명보\n우리올제 김성규 과장
# 5                                             정종인 매니저
# 6       정진호, 심명보, 이한새, 채한길, 우전성, Ahmed. 김의현\n/ 벤더사 직원
# 7       정진호, 심명보, 이한새, 채한길, 우전성, Ahmed. 김의현\n/ 벤더사 직원
# 8                                  중국 법인 최영근\nCCS 이한새
# 9   김효은 매니저\n이한새 매니저\n정진호 매니저\nT-max 이정훈 수석\nVCS 이...
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                   허원범 매니저\n정진호 매니저
# 14                                   심명보 매니저, 이은도 매니저
# 15                임정현 매니저, SPK 박대성 과장, \n오픈베이스 남재하 과장
# 16    양영우 티장,\n이근호 매니저,\n정종인 매니저,\n김지윤 매니저,\n심명보 매니저,
# 17                                            임정현 매니저
# 18                                    이세용 매니저\n박준우 책임
#
#                                            Root Cause  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                 DB block corruption
# 10               Host reboot 발생으로 VM 13대 down time 발생
# 11  paas-prd-rancher02 해당 rancher VM의 메모리사용률이 90%를...
# 12  Bosh health check에 문제가 생긴것을 인지하여 원인 파악 및 장애조치의...
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
#
#                                     Impact (Severity)  \
# 0                                순차별 LB 절체로 인한 영향도 없음
# 1                                 Controller board 교체
# 2                                      Motherboard 교체
# 3                                서비스허브 connect fail증가
# 4                    krcloudprdcomdr1803 메모리 에러 로그 발생
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                   netbackup 수행 안 됨.
# 9                                             DB Down
# 10  VM down time 발생\n\n(이중화 되어 있는 redis DB가 해당 호스트...
# 11                                   rancher 서비스 down
# 12              내수 CCS 주간 5분 간격 배치잡 실패, push 알람 수신 실패
# 13                                 DB Failover중 순단 발생
# 14                         RAID 1 구성으로 서버 다운 없이 작업 진행
# 15  KRCloud-PRD-BL-01 ↔ KRCloud-PRD-L7-01 인터페이스 간 ...
# 16                                               None
# 17  Spine02 Eth50 - CL03-D-01R08 Eth8/1 간 Interfac...
# 18  tibero down 발생\n아래와 같은 에러 발생\n1) THROW. ec=ERR...
#
#                                           Description  \
# 0   self heal 프로세스 진행을 위한 호스트 리붓 필요\n1/19 GIS LB 긴...
# 1   22/01/17 krcloudstgcomdr907.krcloud ipmi 알람 발생...
# 2   21/12/04 KRCloud-PRD-IPMI-R14(10.11.41.194 ) -...
# 3   22/01/12 서비스허브 트래픽 밀림 현상 발생\n==> L4 및 트래픽 점검\n...
# 4   22/02/13 BAREMETAL ccskrbigps03dnp02 vm 리부팅 발생...
# 5   통합계정 장애 관련 변경 및 지원\n변경사항(22/02/25금)\n\nVM Scal...
# 6   NACLOUD 일부 호스트 온도 알람 발생확인\nipmi 확인 시 온도 상승 확인\...
# 7   NACLOUD 일부 호스트 온도 알람 발생확인\nipmi 확인 시 온도 상승 확인\...
# 8   22/04/06 넷백업 수행 안 되는 현상 발생\n22/04/08 넷백업 스위치 d...
# 9   DB block이 깨지면서 해당 block read시 DB down현상 발생\nCC...
# 10  Evacuation 호스트 VM 이관 완료 후 VM 정상상태 확인\n\n영향받은 V...
# 11  paas-prd-rancher 서비스 정상화 및 paas-prd-rancher02 ...
# 12  VM 재생성 과정에서 openstack dhcp 컨테이너 문제 및 keypair 문...
# 13  AWS로의 replication이 진행되지 않아 slot을 drop하지 못하고 계속...
# 14  22/05/30 krcloudprdcomdr1514 log 분석 요청\n22/06/...
# 15  미확인 트래픽, 인터페이스 장애 등으로 오류 발생 가능\n일시적 장애 발생으로 지속...
# 16  22/05/29 2센터 검증계 호스티 다운 발생\n22/05/31 새로운 evacu...
# 17  네트워크 장비간 Interface Down 발생하여 2선(HMC) 확인 요청\nRA...
# 18  22/05/01 tibero down\n22/05/01 1) block 이 깨짐.\...
#
#                                        Ticket          ReviewDated  \
# 0                                KRCLOUD-4117  2022-01-19T00:00:00
# 1                                KRCLOUD-4136  2022-01-26T00:00:00
# 2                  KRCLOUD-3838\nKRCLOUD-4135                 None
# 3   KRCLOUD-4128\nKRCLOUD-4122 \nKRCLOUD-4124                 None
# 4                                KRCLOUD-4272                 None
# 5    KRCLOUD-4390\nKRCLOUD-4391\nKRCLOUD-4392                 None
# 6                                NACLOUD-1263                 None
# 7                                NACLOUD-1263                 None
# 8                  CNCLOUD-1931\nCNCLOUD-1948                 None
# 9                                NACLOUD-1336                 None
# 10                                       None                 None
# 11                                       None                 None
# 12                                       None                 None
# 13                               EUCLOUD-2297                 None
# 14                                       None  2022-06-09T00:00:00
# 15                                       None                 None
# 16                               KRCLOUD-4968  2022-06-09T00:00:00
# 17                                       None                 None
# 18                                       None                 None
#
#                                          ReviewResult
# 0                          self heal 프로세스(호스트 리부팅) 완료
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18  22/05/03 tibero 엔지니어와 복구 작업 후 log 분석 요청\n22/05...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   년도                 19 non-null     object
#  1   월                  19 non-null     object
#  2   리전                 19 non-null     object
#  3   AZ                 19 non-null     object
#  4   테넌트                19 non-null     object
#  5   진행상태               19 non-null     object
#  6   성패                 19 non-null     object
#  7   Task / Job         18 non-null     object
#  8   System / Service   19 non-null     object
#  9   Date               19 non-null     object
#  10  Engineer           16 non-null     object
#  11  Root Cause         4 non-null      object
#  12  Impact (Severity)  15 non-null     object
#  13  Description        19 non-null     object
#  14  Ticket             12 non-null     object
#  15  ReviewDated        4 non-null      object
#  16  ReviewResult       2 non-null      object
# dtypes: object(17)
# memory usage: 2.6+ KB

# %%
df.describe()
# Out:
#            년도   월  리전   AZ  테넌트 진행상태  성패          Task / Job System / Service  \
# count      19  19  19   19   19   19  19                  18               19
# unique      1   6   4    2    2    2   2                  17               18
# top     2022년  6월  KR  1센터  PRD   완료  성공  북미 데이터 센터 쿨러 이상 발생    NA Datacenter
# freq       19   5  13   15   16   18  18                   2                2
#
#                        Date                                       Engineer  \
# count                    19                                             16
# unique                   17                                             15
# top     2022-05-12T00:00:00  정진호, 심명보, 이한새, 채한길, 우전성, Ahmed. 김의현\n/ 벤더사 직원
# freq                      2                                              2
#
#                  Root Cause     Impact (Severity)  \
# count                     4                    15
# unique                    4                    15
# top     DB block corruption  순차별 LB 절체로 인한 영향도 없음
# freq                      1                     1
#
#                                               Description        Ticket  \
# count                                                  19            12
# unique                                                 18            11
# top     NACLOUD 일부 호스트 온도 알람 발생확인\nipmi 확인 시 온도 상승 확인\...  NACLOUD-1263
# freq                                                    2             2
#
#                 ReviewDated                ReviewResult
# count                     4                           2
# unique                    3                           2
# top     2022-06-09T00:00:00  self heal 프로세스(호스트 리부팅) 완료
# freq                      2                           1

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)

# %%
pivot
# Out:
#    리전  합계     비중
# 0  KR   3  100.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.4 변경 관리

# %%
# Data Loading
base_path = r"./data/1_4_202206_변경관리_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#       년도   월  리전   AZ  테넌트 진행상태   성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료   성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료   성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료   성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료   성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료   성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ...           ...
# 120  22년  6월  KR  1센터  PRD   완료   성공  KRCLOUD-5123
# 121  22년  6월  KR  1센터  PRD  진행중  진행중  KRCLOUD-5099
# 122  22년  6월  EU  1센터  PRD  진행중  진행중  EUCLOUD-2482
# 123  22년  6월  CN  1센터  PRD   완료   성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료   성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 121     [국내 MCP] Redis Master 절체 요청          DB
# 122      DB 서버 CPU core / RAM 증설 요청         컴퓨트
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [125 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   년도           125 non-null    object
#  1   월            125 non-null    object
#  2   리전           125 non-null    object
#  3   AZ           125 non-null    object
#  4   테넌트          125 non-null    object
#  5   진행상태         125 non-null    object
#  6   성패           125 non-null    object
#  7   Ticket       119 non-null    object
#  8   Summary      125 non-null    object
#  9   Description  125 non-null    object
# dtypes: object(10)
# memory usage: 9.9+ KB

# %%
df.describe()
# Out:
#          년도    월   리전   AZ  테넌트 진행상태   성패        Ticket      Summary  \
# count   125  125  125  125  125  125  125           119          125
# unique    1    6    7    2    1    3    3           113          107
# top     22년   6월   KR  1센터  PRD   완료   성공  KRCLOUD-4125  신규 LB 생성 요청
# freq    125   37   49  124  125  121  120             2            5
#
#        Description
# count          125
# unique          11
# top          로드밸런서
# freq            55

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)

# %%
pivot
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.5 요청 관리

# %%
# Data Loading
base_path = r"./data/1_5_202206_요청관리_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#         년   월  리전   AZ  테넌트 진행상태  성패  \
# 0     22년  1월  CN  1센터  PRD   완료  성공
# 1     22년  1월  CN  1센터  STG   완료  성공
# 2     22년  1월  CN  1센터  STG   완료  성공
# 3     22년  1월  CN  1센터  STG   완료  성공
# 4     22년  1월  CN  1센터  STG   완료  성공
# ...   ...  ..  ..  ...  ...  ...  ..
# 3462  22년  6월  SG  1센터  PRD   완료  성공
# 3463  22년  6월  SG  1센터  PRD   완료  성공
# 3464  22년  6월  SG  1센터  PRD   완료  성공
# 3465  22년  6월  SG  1센터  PRD   완료  성공
# 3466  22년  6월  SG  1센터  PRD   완료  성공
#
#                                                 Summary        Ticket
# 0                              중국 PRD_CCS DB ZONE VM 배치  CNCLOUD-1303
# 1       cncloudstgComC01 - Storage controller Error log  CNCLOUD-1334
# 2     cncloudstgcomc04_IPMI and Zabbix Monitoring st...  CNCLOUD-1450
# 3                                 중국 검증계 UCS 유지보수 계약 만료  CNCLOUD-1595
# 4     cncloudstgcomc01_RMA 를 위한 Host empty작업(VM live...  CNCLOUD-1688
# ...                                                 ...           ...
# 3462                                      [AU] VM 회수 요청   SGCLOUD-990
# 3463                            [AU/SG/ID] 방화벽 추가 오픈 요청   SGCLOUD-991
# 3464                                          방화벽 등록 요청   SGCLOUD-993
# 3465                                    [SG] VM list 확인   SGCLOUD-995
# 3466                                           호주 VM 회수   SGCLOUD-997
#
# [3467 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3467 entries, 0 to 3466
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   년        3467 non-null   object
#  1   월        3467 non-null   object
#  2   리전       3467 non-null   object
#  3   AZ       3467 non-null   object
#  4   테넌트      3467 non-null   object
#  5   진행상태     3467 non-null   object
#  6   성패       3467 non-null   object
#  7   Summary  3467 non-null   object
#  8   Ticket   3460 non-null   object
# dtypes: object(9)
# memory usage: 243.9+ KB

# %%
df.describe()
# Out:
#            년     월    리전    AZ   테넌트  진행상태    성패         Summary       Ticket
# count   3467  3467  3467  3467  3467  3467  3467            3467         3460
# unique     1     6     7     2     3     1     3            2781         2784
# top      22년    3월    KR   1센터   PRD    완료    성공  [AU] 방화벽 해제 요청  SGCLOUD-499
# freq    3467   884  1096  3435  2667  3467  3358              43           41

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)

# %%
pivot
# Out:
#    리전   합계    비중
# 0  EU  116  28.0
# 1  KR  102  25.0
# 2  SG   84  20.0
# 3  CN   52  12.0
# 4  NA   45  11.0
# 5  RU   15   4.0
# 6  IN    2   0.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.6 자산 관리 - VM

# %%
# Data Loading
base_path = r"./data/1_6_202206_자산관리_VM_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#       년도   월  리전   AZ  테넌트   count
# 0    22년  1월  KR  1센터  PRD  2117.0
# 1    22년  1월  KR  1센터  STG  2145.0
# 2    22년  1월  KR  1센터  DEV     NaN
# 3    22년  1월  KR  2센터  PRD     NaN
# 4    22년  1월  KR  2센터  STG     NaN
# ..   ...  ..  ..  ...  ...     ...
# 109  22년  6월  RU  1센터  STG    86.0
# 110  22년  6월  RU  1센터  DEV     NaN
# 111  22년  6월  SG  1센터  PRD   243.0
# 112  22년  6월  SG  1센터  STG   236.0
# 113  22년  6월  SG  1센터  DEV     NaN
#
# [114 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      114 non-null    object
#  1   월       114 non-null    object
#  2   리전      114 non-null    object
#  3   AZ      114 non-null    object
#  4   테넌트     114 non-null    object
#  5   count   78 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 5.5+ KB

# %%
df.describe()
# Out:
#              count
# count    78.000000
# mean    569.564103
# std     707.263183
# min      78.000000
# 25%     199.500000
# 50%     262.000000
# 75%     513.500000
# max    2929.000000

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)

# %%
pivot
# Out:
#    리전      합계    비중
# 0  KR  1931.0  51.0
# 1  NA   581.0  15.0
# 2  EU   530.0  14.0
# 3  CN   393.0  10.0
# 4  SG   243.0   6.0
# 5  RU    78.0   2.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.6 자산 관리 - DB

# %%
# Data Loading
base_path = r"./data/1_6_202206_자산관리_DB_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#       년도   월  리전   AZ  테넌트        DBMS  count
# 0    22년  1월  KR  1센터  PRD  PostgreSQL  110.0
# 1    22년  1월  KR  1센터  PRD      Tibero   28.0
# 2    22년  1월  KR  1센터  PRD       Maria   32.0
# 3    22년  1월  KR  1센터  PRD       Redis   97.0
# 4    22년  1월  KR  1센터  PRD       Mongo   84.0
# ..   ...  ..  ..  ...  ...         ...    ...
# 625  22년  6월  SG  1센터  DEV  PostgreSQL    0.0
# 626  22년  6월  SG  1센터  DEV      Tibero    0.0
# 627  22년  6월  SG  1센터  DEV       Maria    0.0
# 628  22년  6월  SG  1센터  DEV       Redis    0.0
# 629  22년  6월  SG  1센터  DEV       Mongo    0.0
#
# [630 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      630 non-null    object
#  1   월       630 non-null    object
#  2   리전      630 non-null    object
#  3   AZ      630 non-null    object
#  4   테넌트     630 non-null    object
#  5   DBMS    630 non-null    object
#  6   count   630 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 34.6+ KB

# %%
df.describe()
# Out:
#             count
# count  630.000000
# mean     9.695238
# std     19.908035
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%     11.750000
# max    122.000000

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)

# %%
pivot
# Out:
#    리전     합계    비중
# 0  KR  407.0  67.0
# 1  SG   57.0   9.0
# 2  EU   48.0   8.0
# 3  CN   43.0   7.0
# 4  NA   41.0   7.0
# 5  RU    8.0   1.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.6 자산 관리 - K8s

# %%
import datetime
from chart import *

# Data Loading
base_path = r"./data/1_6_202206_자산관리_k8s_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#       년도   월  리전   AZ  테넌트  구분              k8s클러스터명 K8S Version  Node Qty  \
# 0    22년  6월  EU  1센터  PRD  VM                 local     v1.19.6       3.0
# 1    22년  6월  EU  1센터  PRD  VM       gcseu-vtwin-prd     v1.19.6       6.0
# 2    22년  6월  EU  1센터  PRD  VM  gcseu-svchubidmz-prd    v1.17.16       6.0
# 3    22년  6월  EU  1센터  PRD  VM  gcseu-svchubcore-prd    v1.17.16       6.0
# 4    22년  6월  EU  1센터  PRD  VM     gcseu-dkc2gpl-prd    v1.19.15       7.0
# ..   ...  ..  ..  ...  ...  ..                   ...         ...       ...
# 129  22년  6월  KR  2센터  STG  VM               ccs-dev      1.19.6      16.0
# 130  22년  6월  KR  2센터  STG  VM               CCS-stg      1.19.6      32.0
# 131  22년  6월  KR  2센터  STG  VM     ccskr2-svchub-stg      1.19.6      12.0
# 132  22년  6월  KR  2센터  STG  VM    ccssre-hubble-test      1.19.6       4.0
# 133  22년  6월  KR  2센터  STG  VM                 local      1.19.6       3.0
#
#     CPU 할당율 (Cores)  CPU 사용률 (Cores)  CPU 사용 백분율  RAM 할당율(GB)  RAM 사용률(GB)  \
# 0              12.0              3.5    0.291667         46.7          5.1
# 1              24.0              1.0    0.041667         94.0          4.2
# 2              12.0              1.0    0.083333         46.7          0.2
# 3              24.0              1.8    0.075000         94.0          0.8
# 4              64.0             10.3    0.160938        251.0         29.7
# ..              ...              ...         ...          ...          ...
# 129           104.0             27.1    0.260577        405.0         32.2
# 130           240.0             15.2    0.063333        921.6        204.8
# 131           288.0            159.0    0.552083       1126.4        307.2
# 132            12.0              4.7    0.391667         46.2          5.7
# 133            12.0              2.8    0.233333         46.2          1.6
#
#      RAM 사용 백분율   담당팀     배포방식 렌처 모니터링 설치 유무 사용자 클러스터 모니터링 설치 유무
# 0      0.109208  None  Rancher             X                   X
# 1      0.044681  None  Rancher          None                   X
# 2      0.004283  None  Rancher          None                   X
# 3      0.008511  None  Rancher          None                   X
# 4      0.118327  None  Rancher          None                   X
# ..          ...   ...      ...           ...                 ...
# 129    0.079506  None     None          None                   X
# 130    0.222222  None     None          None                   X
# 131    0.272727  None     None          None                   X
# 132    0.123377  None     None          None                   X
# 133    0.034632  None     None          None                   X
#
# [134 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   년도                   134 non-null    object
#  1   월                    134 non-null    object
#  2   리전                   134 non-null    object
#  3   AZ                   134 non-null    object
#  4   테넌트                  134 non-null    object
#  5   구분                   134 non-null    object
#  6   k8s클러스터명             134 non-null    object
#  7   K8S Version          134 non-null    object
#  8   Node Qty             134 non-null    float64
#  9   CPU 할당율 (Cores)      134 non-null    object
#  10  CPU 사용률 (Cores)      133 non-null    float64
#  11  CPU 사용 백분율           134 non-null    float64
#  12  RAM 할당율(GB)          133 non-null    float64
#  13  RAM 사용률(GB)          133 non-null    float64
#  14  RAM 사용 백분율           133 non-null    float64
#  15  담당팀                  4 non-null      object
#  16  배포방식                 40 non-null     object
#  17  렌처 모니터링 설치 유무        4 non-null      object
#  18  사용자 클러스터 모니터링 설치 유무  134 non-null    object
# dtypes: float64(6), object(13)
# memory usage: 20.0+ KB

# %%
df.describe()
# Out:
#          Node Qty  CPU 사용률 (Cores)  CPU 사용 백분율  RAM 할당율(GB)  RAM 사용률(GB)  \
# count  134.000000       133.000000  134.000000   133.000000   133.000000
# mean     6.776119        21.271429    0.264873   212.812030    50.327068
# std      5.489076        74.629647    0.248679   659.045067   212.844609
# min      1.000000         0.400000    0.000000     1.500000     0.000000
# 25%      3.000000         1.000000    0.083333    37.700000     0.200000
# 50%      6.000000         3.500000    0.188333    46.700000     3.800000
# 75%      8.000000        11.300000    0.391250   123.000000    16.700000
# max     38.000000       700.000000    0.980000  5222.400000  1843.200000
#
#        RAM 사용 백분율
# count  133.000000
# mean     0.138122
# std      0.183956
# min      0.000000
# 25%      0.008850
# 50%      0.061008
# 75%      0.183274
# max      0.794212

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)

# %%
pivot
# Out:
#    리전  합계    비중
# 0  KR  25  48.0
# 1  CN   8  15.0
# 2  NA   7  13.0
# 3  SG   7  13.0
# 4  EU   5  10.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.7 용량 관리

# %%
import datetime
from chart import *

# Data Loading
base_path = r"./data/1_7_202206_용량관리_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)
df
# Out:
#      년도   월  리전   AZ  테넌트 진행상태 성패          자원유형 Ticket  \
# 0   22년  1월  KR  1.0  PRD   완료  -     Host(CPU)      -
# 1   22년  1월  KR  1.0  PRD   완료  -  Host(Memory)      -
# 2   22년  1월  KR  1.0  PRD   완료  -       Storage      -
# 3   22년  1월  KR  1.0  PRD   완료  -     Host(CPU)      -
# 4   22년  1월  NA  NaN  PRD   완료  -       Storage      -
# ..  ...  ..  ..  ...  ...  ... ..           ...    ...
# 92  22년  6월  KR  1.0  PRD   완료  -     Host(CPU)      -
# 93  22년  6월  KR  1.0  PRD   완료  -  Host(Memory)      -
# 94  22년  6월  KR  1.0  PRD   완료  -       Storage      -
# 95  22년  6월  KR  1.0  PRD   완료  -   Host(Chage)      -
# 96  22년  6월  CN  NaN  PRD   완료  -       Storage      -
#
#                                               Summary Description
# 0     신운영계 - 자원증설 필요\n\nCPU Util 80% 초과 - 신규 VM 생성 중단    자원 증설 필요
# 1                     신운영계 - 자원증설 필요\n\nMemory 60% 초과    자원 증설 필요
# 2          신운영계 - 자원증설 필요\n\nNVMe Storage Util 60% 근접    자원 증설 필요
# 3        구운영계 - 자원부족\n\nCPU Util 75% 초과 - 신규 VM 생성 중단       자원 부족
# 4                     자원증설 리뷰 필요\n\nNAPRD Util 50% 초과    증설 리뷰 필요
# ..                                                ...         ...
# 92                  신운영계 - 자원증설 필요\n\nCPU Util 85% 초과    자원 증설 필요
# 93                    신운영계 - 자원증설 필요\n\nMemory 60% 초과    자원 증설 필요
# 94     신운영계 - 자원증설 필요\n\naggr_node01_NVMe_date 80% 초과    자원 증설 필요
# 95  Pivotal - 1,2,3 VM/CPU/Memory >> PAAS 존으로 편입(0...    자원 증설 필요
# 96  CN 운영계 - 스토리지 자원증설 필요\n\nCCS_SAS 사용률 80% 초과 → ...    자원 증설 필요
#
# [97 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   년도           97 non-null     object
#  1   월            97 non-null     object
#  2   리전           97 non-null     object
#  3   AZ           29 non-null     float64
#  4   테넌트          97 non-null     object
#  5   진행상태         97 non-null     object
#  6   성패           86 non-null     object
#  7   자원유형         97 non-null     object
#  8   Ticket       97 non-null     object
#  9   Summary      97 non-null     object
#  10  Description  97 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 8.5+ KB

# %%
df.describe()
# Out:
#          AZ
# count  29.0
# mean    1.0
# std     0.0
# min     1.0
# 25%     1.0
# 50%     1.0
# 75%     1.0
# max     1.0

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)
pivot
# Out:
#    리전  진행상태
# 0  CN     2
# 1  EU     3
# 2  KR     4
# 3  NA     2
# 4  RU     1
#    리전  합계    비중
# 0  KR   4  33.0
# 1  EU   3  25.0
# 2  CN   2  17.0
# 3  NA   2  17.0
# 4  RU   1   8.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.8 백업 관리

# %%
import datetime
from chart import *

# Data Loading
base_path = r"./data/1_8_202206_백업관리_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#         연도   월  리전   AZ  테넌트      DBType 백업 정상 유무           Instance  \
# 0    2022년  6월  KR  1센터  PRD  PostgreSQL        O  ccskrevappdatap01
# 1    2022년  6월  KR  1센터  PRD  PostgreSQL        O  ccskrevappdatap02
# 2    2022년  6월  KR  1센터  PRD  PostgreSQL        O     ccskrccspdbp01
# 3    2022년  6월  KR  1센터  PRD  PostgreSQL        O     ccskrccspdbp02
# 4    2022년  6월  KR  1센터  PRD  PostgreSQL        O  ccskrtrafficdbp01
# ..     ...  ..  ..  ...  ...         ...      ...                ...
# 683  2022년  6월  SG  1센터  PRD       Mongo        X   ccspidmongodbp03
# 684  2022년  6월  SG  1센터  PRD       Mongo        X      ccsidbatchp01
# 685  2022년  6월  SG  1센터  PRD       Mongo        X    ccsaumongodbp01
# 686  2022년  6월  SG  1센터  PRD       Mongo        X    ccsaumongodbp02
# 687  2022년  6월  SG  1센터  PRD       Mongo        X    ccsaumongodbp03
#
#                 IP 백업 주기\n(full/archive)                        비고
# 0     10.11.26.180               주1/매10분                      None
# 1     10.11.26.181                  None                   standby
# 2     10.11.60.250               주1/매10분                      None
# 3      10.11.60.55                  None                   standby
# 4     10.11.60.251               주1/매10분                      None
# ..             ...                   ...                       ...
# 683   10.107.61.83                  None  해외리전은 백업 스토리지 구성 후 작업 예정
# 684  10.107.62.180                  None            담당자가 설치 형상이 다름
# 685   10.107.70.46                  None  해외리전은 백업 스토리지 구성 후 작업 예정
# 686  10.107.71.73                   None  해외리전은 백업 스토리지 구성 후 작업 예정
# 687  10.107.70.87                   None  해외리전은 백업 스토리지 구성 후 작업 예정
#
# [688 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   연도                    688 non-null    object
#  1   월                     688 non-null    object
#  2   리전                    688 non-null    object
#  3   AZ                    688 non-null    object
#  4   테넌트                   688 non-null    object
#  5   DBType                688 non-null    object
#  6   백업 정상 유무              594 non-null    object
#  7   Instance              682 non-null    object
#  8   IP                    682 non-null    object
#  9   백업 주기
# (full/archive)  149 non-null    object
#  10  비고                    334 non-null    object
# dtypes: object(11)
# memory usage: 59.2+ KB

# %%
df.describe()
# Out:
#            연도    월   리전   AZ  테넌트 DBType 백업 정상 유무             Instance  \
# count     688  688  688  688  688    688      594                  682
# unique      1    1    6    2    1      7        2                  665
# top     2022년   6월   KR  1센터  PRD  Redis        O  ccskrsvchubredisp02
# freq      688  688  468  633  688    194      298                    2
#
#                   IP 백업 주기\n(full/archive)       비고
# count            682                   149      334
# unique           671                    14       50
# top     10.107.19.28               주1/매10분  standby
# freq               2                    61       66

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)
pivot
# Out:
#    리전  DBType
# 0  CN      45
# 1  EU      46
# 2  KR     468
# 3  NA      54
# 4  RU      18
# 5  SG      57
#    리전   합계    비중
# 0  KR  468  68.0
# 1  SG   57   8.0
# 2  NA   54   8.0
# 3  EU   46   7.0
# 4  CN   45   7.0
# 5  RU   18   3.0

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.9 보안 관리

# %%
# Data Loading
base_path = r"./data/1_9_202206_보안관리_0720_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
df
# Out:
#      년도   월        리전   AZ    테넌트 진행상태  성패           Ticket  \
# 0   22년  1월        KR  1센터    DEV   완료  성공    KRCLOUD-4134
# 1   22년  1월        KR  1센터    STG   완료  성공    KRCLOUD-4134
# 2   22년  2월    Global  1센터    ALL   완료  성공    KRCLOUD-4377
# 3   22년  2월        CN  1센터    STG   완료  성공    CNCLOUD-1801
# 4   22년  2월        CN  1센터    PRD   완료  성공    CNCLOUD-1801
# ..  ...  ..       ...  ...    ...  ...  ..              ...
# 63  22년  6월        KR  1센터    STG  진행중        KRCLOUD-4612
# 64  22년  6월        CN  1센터    STG  진행중        CNCLOUD-2010
# 65  22년  6월        CN  1센터    PRD  진행중        CNCLOUD-2010
# 66  22년  6월        CN  1센터    PRD  진행중        CNCLOUD-2005
# 67  22년  6월        KR  1센터    PRD  진행중         KRCLOUD-5113
#
#                                     Summary Description
# 0                   EV 플랫폼 인프라 보안 점검 요청의 건         보안점검
# 1                   EV 플랫폼 인프라 보안 점검 요청의 건         보안점검
# 2              글로벌 CCS OS 보안 설정 관련 확인 요청의 건        보안점검
# 3                       공신부 점검 지원 요청 드립니다.         보안점검
# 4                       공신부 점검 지원 요청 드립니다.         보안점검
# ..                                      ...         ...
# 63                  EV 플랫폼 인프라 보안 점검 요청의 건         보안점검
# 64   클라우드 플랫폼(OpenStack에 관련 보안 설정 현황 확인 요청         보안점검
# 65   클라우드 플랫폼(OpenStack에 관련 보안 설정 현황 확인 요청         보안점검
# 66     gcscntmsdbp01 10.107.253.48 DB보안 조치         보안점검
# 67             보안정기점검 관련 I-SAMS 내 취약점 조치 요청        보안점검
#
# [68 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   년도           68 non-null     object
#  1   월            68 non-null     object
#  2   리전           68 non-null     object
#  3   AZ           68 non-null     object
#  4   테넌트          68 non-null     object
#  5   진행상태         68 non-null     object
#  6   성패           68 non-null     object
#  7   Ticket       66 non-null     object
#  8   Summary      68 non-null     object
#  9   Description  68 non-null     object
# dtypes: object(10)
# memory usage: 5.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   년도           68 non-null     object
#  1   월            68 non-null     object
#  2   리전           68 non-null     object
#  3   AZ           68 non-null     object
#  4   테넌트          68 non-null     object
#  5   진행상태         68 non-null     object
#  6   성패           68 non-null     object
#  7   Ticket       66 non-null     object
#  8   Summary      68 non-null     object
#  9   Description  68 non-null     object
# dtypes: object(10)
# memory usage: 5.4+ KB

# %%
# Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
pivot = getPivotTable(df)
pivot
# Out:
# Empty DataFrame
# Columns: [리전]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 # Pivoting - [df['월']=='6월') & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
# ----> 2 pivot = getPivotTable(df)
#       3 pivot
#
# File C:\Workspace\p-python2doc\chart.py:58, in getPivotTable(df)
#      56 # filtered.describe()
#      57 print(pivotTable)
# ---> 58 pivotTable.columns = ['리전', '합계']
#      59 pivotTable.sort_values(by=['합계'], ascending=False, inplace=True)
#      60 pivotTable.reset_index(drop=True, inplace=True)
#
# File C:\Workspace\p-python2doc\venv\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File C:\Workspace\p-python2doc\venv\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File C:\Workspace\p-python2doc\venv\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File C:\Workspace\p-python2doc\venv\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File C:\Workspace\p-python2doc\venv\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 2 elements

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')

# %% [markdown]
# ## 1.10 하드웨어 정기정검

# %%
# Data Loading
base_path = r"./data/202206_변경관리_0708_01.ods"
sheet = '6월집계'

df = read_ods(base_path, sheet, headers=True)

# %%
# ETL
total = Data.count()
data = getdata()
chart = getTable(data)

# %% [markdown]
# ### 비중 :: Piot Table

# %%
pivot = getPivotTable(df)

# %%
source = pivot
chart = get_pieChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save(f'./charts/mon_{y}_{m}_{d}_1.png')
# Out:
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.

# %%
document.add_paragraph('1.1 서비스 관리', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### 시계열 :: LineChart

# %%
pTable
# Out:
#    리전  합계    비중
# 0  KR  11  32.0
# 1  SG   9  26.0
# 2  EU   7  21.0
# 3  CN   5  15.0
# 4  NA   2   6.0

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/2.png')
document.add_picture('charts/2.png')

# %%
df_filtered[df_filtered['월'] == '6월'].sort_values(['리전']).reset_index()
# Out:
#     index   년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0     105  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2078
# 1     117  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2063
# 2     114  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2113
# 3     100  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2045
# 4     123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 5      91  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2309
# 6     115  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2523
# 7      95  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2322
# 8     111  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2326
# 9     110  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2451
# 10    101  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2179
# 11    102  22년  6월  EU  1센터  PRD   완료  성공  EUCLOUD-2379
# 12    120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 13    116  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5112
# 14    106  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5038
# 15     88  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4884
# 16    124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
# 17     98  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4980
# 18     89  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4938
# 19     90  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4935
# 20     93  22년  6월  KR  1센터  PRD   완료  성공          None
# 21     96  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4888
# 22     94  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-4952
# 23    119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 24    113  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1477
# 25    112  22년  6월  SG  1센터  PRD   완료  성공  SGCLOUD-1012
# 26     97  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-934
# 27     92  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-923
# 28    109  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 29    118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 30    108  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-987
# 31    107  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-952
# 32    104  22년  6월  SG  1센터  PRD   완료  성공   SGCLOUD-878
# 33    103  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-959
#
#                                         Summary Description
# 0                     DB VM 볼륨 이전 ( SSD -> SAS)          DB
# 1                    [API G/W] LB SSL 인증서 갱신 요청       로드밸런서
# 2                     Rancher-webhook-tls 인증서갱신     rancher
# 3                                  VM 리소스 증설 요청         컴퓨트
# 4                                  LB 인증서 갱신 요청       로드밸런서
# 5                              GOMS LB 멤버 추가 요청       로드밸런서
# 6                     Rancher-webhook-tls 인증서갱신     rancher
# 7                               CCS 유휴 자원 반납 요청         컴퓨트
# 8                                  LB 신규 인증서 추가       로드밸런서
# 9                   Pre-filter 적용 GIS(GTC-C) 요청         방화벽
# 10                                 Volume 회수 요청         컴퓨트
# 11                                  신규 LB 생성 요청       로드밸런서
# 12                       [API G/W] LB URL 분기 요청       로드밸런서
# 13                    Rancher-webhook-tls 인증서갱신     rancher
# 14  Daily Vacuum freeze 수행 횟수 조정 및 파라미터 값 조정 요청          DB
# 15                                 LB 인증서 갱신 요청       로드밸런서
# 16                          VR SBS LB 인증서 적용 요청       로드밸런서
# 17                      [ccvR] 장비 메인보드 교체 작업 요청         컴퓨트
# 18                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 19                              FMS LB 신규 생성 요청       로드밸런서
# 20                             TAS 플랫폼 Shutoff          TAS
# 21                                 VM CPU 증설 요청         컴퓨트
# 22              [국내 MCP] CARPAY 웹서버 LB 신규 생성 요청       로드밸런서
# 23                                 기존 LB에 멤버 추가       로드밸런서
# 24                    Rancher-webhook-tls 인증서갱신     rancher
# 25                    Rancher-webhook-tls 인증서갱신     rancher
# 26                               컨트롤러 노드 Reboot         컴퓨트
# 27           LB Method 변경 및 Rancher api pod 재기동       로드밸런서
# 28                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 29                                     VM 회수 요청         컴퓨트
# 30                        SSL 인증서 프로토콜 보안 적용 요청       로드밸런서
# 31                                VM Disk 증설 요청         컴퓨트
# 32                       F5 취약점 대응에 의한 펌웨어 업데이트       로드밸런서
# 33                                  신규 LB 생성 요청       로드밸런서

# %% [markdown]
# ### 시계열 :: BarChart

# %%
source=pTable
chart = get_barChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/3.png')
document.add_picture('charts/3.png')

# %% [markdown]
# ### 시계열 - LineChart or BarChart

# %% [markdown]
# ### ALL

# %%
regex = '^(KR|CN|NA|EU|SG|RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/4.png')
document.add_picture('charts/4.png')

# %%
source
# Out:
#       년도   월  리전   AZ  테넌트 진행상태  성패        Ticket  \
# 0    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# 1    22년  1월  CN  1센터  PRD   완료  성공  CNCLOUD-1736
# 2    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4129
# 3    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4137
# 4    22년  1월  KR  1센터  PRD   완료  성공  KRCLOUD-4125
# ..   ...  ..  ..  ...  ...  ...  ..           ...
# 118  22년  6월  SG  1센터  PRD   완료  성공    SGCLOU-990
# 119  22년  6월  NA  1센터  PRD   완료  성공  NACLOUD-1448
# 120  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5123
# 123  22년  6월  CN  1센터  PRD   완료  성공  CNCLOUD-2103
# 124  22년  6월  KR  1센터  PRD   완료  성공  KRCLOUD-5110
#
#                             Summary Description
# 0            GIS LB 인입 제어(맵 업로드) 요청       로드밸런서
# 1           [중국 디지털키 2] 신규 LB 생성 요청       로드밸런서
# 2       TAS 플랫폼 Router VM 리소스 증설 요청         컴퓨트
# 3    TAS 플랫폼 isolation VM 리소스 증설 요청         컴퓨트
# 4                    GIS LB 긴급 지원요청       로드밸런서
# ..                              ...         ...
# 118                        VM 회수 요청         컴퓨트
# 119                    기존 LB에 멤버 추가       로드밸런서
# 120          [API G/W] LB URL 분기 요청       로드밸런서
# 123                    LB 인증서 갱신 요청       로드밸런서
# 124             VR SBS LB 인증서 적용 요청       로드밸런서
#
# [121 rows x 10 columns]

# %%
# Write to Word
document.add_paragraph('1.1 모니터링', style='List Number')
document.add_paragraph(f'6월: 총 {total}', style='List Bullet')
document.add_picture(f'./charts/mon_{y}_{m}_{d}_1.png')

# %% [markdown]
# ### by Region

# %%
regions = df['리전'].unique()

for region in regions:
    print(region)
# Out:
# KR
# CN
# NA
# EU
# SG
# RU
# Global

# %% [markdown]
# #### KR

# %%
regex = '^(KR|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/5.png')
document.add_picture('charts/5.png')

# %% [markdown]
# #### CN

# %%
regex = '^(CN|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/6.png')
document.add_picture('charts/6.png')

# %% [markdown]
# #### NA

# %%
regex = '^(NA|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/7.png')
document.add_picture('charts/7.png')

# %% [markdown]
# #### EU

# %%
regex = '^(EU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/8.png')
document.add_picture('charts/8.png')

# %% [markdown]
# #### SG

# %%
regex = '^(SG|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/9.png')
document.add_picture('charts/9.png')

# %% [markdown]
# #### RU

# %%
regex = '^(RU|Global)'
df_filtered = df[df['리전'].apply(lambda x: True if re.search(regex, x) else False) & (df['테넌트']== 'PRD') & (df['진행상태']=='완료')]
source = df_filtered
chart = get_lineChart(source)
chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('charts/10.png')
document.add_picture('charts/10.png')

# %%
document.save('word.docx')
